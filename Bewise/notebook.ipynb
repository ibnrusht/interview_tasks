# %% [markdown]
# Import df

# %%
import pandas as pd

df = pd.read_csv("test_data.csv")
df.head(20)
# Out:
#     dlg_id  line_n     role                                               text
# 0        0       0  manager                                               Алло
# 1        0       1   client                                  Алло здравствуйте
# 2        0       2  manager                                        Добрый день
# 3        0       3   client  Меня зовут ангелина компания диджитал бизнес з...
# 4        0       4  manager                                                Ага
# 5        0       5   client  Угу ну возможно вы рассмотрите и другие вариан...
# 6        0       6  manager  Да мы работаем с компанией которая нам подлива...
# 7        0       7  manager  Как как бы уже до этого момента работаем все у...
# 8        0       8   client      Угу а на что вы обращаете внимание при выборе
# 9        0       9  manager                                         Как бы нет
# 10       0      10  manager  Да на выбор я уже не обращаю внимание я уже до...
# ...

# %%
len(df)
# Out:
# 480
